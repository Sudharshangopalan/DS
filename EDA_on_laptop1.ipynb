# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
l=pd.read_csv("/content/laptop_dataset.csv")
l
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
l.shape
# Out:
# (1303, 12)

# %%
l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
l.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
l.head(10)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5           5    Acer   Notebook    15.6                            1366x768
# 6           6   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7           7   Apple  Ultrabook    13.3                            1440x900
# 8           8    Asus  Ultrabook    14.0                   Full HD 1920x1080
# 9           9    Acer  Ultrabook    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# ...

# %%
l.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
l.duplicated().sum()
# Out:
# np.int64(0)

# %%
l["Company"].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
sns.countplot(l["Company"])
# Out:
# <Axes: xlabel='count', ylabel='Company'>

# %%
sns.boxplot(l["Company"])
# Out:
# <Axes: ylabel='Company'>

# %%
l["Company"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
l.groupby("Company")["TypeName"].value_counts()
# Out:
# Company    TypeName
# Acer       Notebook               78
#            2 in 1 Convertible      8
#            Gaming                  8
#            Netbook                 5
#            Ultrabook               4
# Apple      Ultrabook              21
# Asus       Notebook               67
#            Gaming                 54
#            Ultrabook              20
#            2 in 1 Convertible     13
#            Netbook                 4
# Chuwi      Notebook                3
# Dell       Notebook              165
#            Ultrabook              49
#            Gaming                 40
#            2 in 1 Convertible     30
#            Workstation            11
#            Netbook                 2
# Fujitsu    Notebook                3
# Google     Ultrabook               3
# HP         Notebook              184
#            Ultrabook              36
#            2 in 1 Convertible     19
#            Workstation            14
#            Gaming                 12
# ...

# %%
l["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
l.groupby("TypeName")["Price"].value_counts()
# Out:
# TypeName            Price
# 2 in 1 Convertible  79866.720     6
#                     95850.720     6
#                     53226.720     4
#                     69210.720     4
#                     33992.640     3
#                                  ..
# Workstation         154458.720    1
#                     162770.400    1
#                     175770.720    1
#                     210424.032    1
#                     233845.920    1
# Name: count, Length: 952, dtype: int64

# %%
l["TypeName"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
l["Inches"].value_counts()
# Out:
# Inches
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 13.5      6
# 12.0      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
l["Inches"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Inches'>

# %%
l.groupby("Company")["Inches"].value_counts().head(20)
# Out:
# Company  Inches
# Acer     15.6       66
#          14.0       13
#          11.6        9
#          17.3        9
#          13.3        6
# Apple    13.3       10
#          12.0        6
#          15.4        4
#          11.6        1
# Asus     15.6       74
#          17.3       42
#          14.0       19
#          13.3       13
#          11.6        6
#          12.5        3
#          14.1        1
# Chuwi    15.6        2
#          12.3        1
# Dell     15.6      187
#          13.3       48
# Name: count, dtype: int64

# %%
l["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
l.groupby("Company")["ScreenResolution"].value_counts().head(15).sort_values(ascending=False)
# Out:
# Company  ScreenResolution
# Asus     Full HD 1920x1080                            75
# Acer     1366x768                                     45
# Asus     1366x768                                     38
#          IPS Panel Full HD 1920x1080                  25
# Acer     IPS Panel Full HD 1920x1080                  22
#          Full HD 1920x1080                            21
#          IPS Panel Full HD / Touchscreen 1920x1080     8
# Apple    IPS Panel Retina Display 2560x1600            6
#          IPS Panel Retina Display 2304x1440            6
#          IPS Panel Retina Display 2880x1800            4
#          1440x900                                      4
# Acer     IPS Panel 1366x768                            3
#          1600x900                                      2
#          IPS Panel Touchscreen 1366x768                2
# Apple    1366x768                                      1
# Name: count, dtype: int64

# %%
l["Cpu"].value_counts().head(10)
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     134
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
# Intel Core i5 6200U 2.3GHz      68
# Intel Core i3 6006U 2GHz        64
# Intel Core i7 6500U 2.5GHz      49
# Intel Core i7 6700HQ 2.6GHz     43
# Intel Core i3 7100U 2.4GHz      37
# Name: count, dtype: int64

# %%
l["Cpu"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Cpu'>

# %%
l.groupby("Ram")["Cpu"].value_counts().head(20)
# Out:
# Ram   Cpu
# 12GB  Intel Core i7 7700HQ 2.8GHz     7
#       Intel Core i7 7500U 2.7GHz      6
#       Intel Core i7 6600U 2.6GHz      3
#       AMD A12-Series 9720P 3.6GHz     2
#       Intel Core i5 7200U 2.5GHz      2
#       Intel Core i5 8250U 1.6GHz      2
#       Intel Core i5 7300HQ 2.5GHz     1
#       Intel Core i7 6700HQ 2.6GHz     1
#       Intel Core i7 8550U 1.8GHz      1
# 16GB  Intel Core i7 7700HQ 2.8GHz    72
#       Intel Core i7 7500U 2.7GHz     29
#       Intel Core i7 6700HQ 2.6GHz    21
#       Intel Core i7 8550U 1.8GHz     20
#       Intel Core i7 6500U 2.5GHz      9
#       Intel Core i7 6600U 2.6GHz      6
#       Intel Core i7 6820HK 2.7GHz     5
#       Intel Core i7 6820HQ 2.7GHz     5
#       Intel Core i7 7600U 2.8GHz      5
#       Intel Core i7 7820HK 2.9GHz     4
#       Intel Core i7 7Y75 1.3GHz       3
# Name: count, dtype: int64

# %%
l["Ram"].value_counts()
# Out:
# Ram
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
l["Ram"].value_counts().plot(kind="pie",legend="ram")
# Out:
# <Axes: ylabel='count'>

# %%
l.groupby("Ram")["Company"].value_counts()
# Out:
# Ram   Company
# 12GB  HP         6
#       Lenovo     6
#       Asus       5
#       Dell       5
#       Acer       3
#                 ..
# 8GB   Fujitsu    2
#       Google     2
#       Huawei     2
#       LG         2
#       Razer      1
# Name: count, Length: 70, dtype: int64

# %%
l.groupby("Ram")["Company"].value_counts().head(15)
# Out:
# Ram   Company
# 12GB  HP          6
#       Lenovo      6
#       Asus        5
#       Dell        5
#       Acer        3
# 16GB  Dell       54
#       Lenovo     39
#       Asus       35
#       MSI        31
#       HP         13
#       Toshiba     8
#       Acer        4
#       Apple       4
#       Razer       4
#       Samsung     4
# Name: count, dtype: int64

# %%
l.groupby("Ram")["Company"].value_counts().head(10).plot(kind="barh",legend="company")
# Out:
# <Axes: ylabel='Ram,Company'>

# %%
l['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
l['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
l['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
l['OpSys'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='OpSys'>

# %%
l.groupby('OpSys')["Price"].value_counts().tail(15)
# Out:
# OpSys      Price
# Windows 7  210424.0320    1
#            233845.9200    1
# macOS      47895.5232     1
#            61735.5360     1
#            67260.6720     1
#            71378.6832     1
#            75604.3200     1
#            80452.8000     1
#            80908.3440     1
#            96095.8080     1
#            104370.1920    1
#            108691.2000    1
#            130001.6016    1
#            135195.3360    1
#            152274.2400    1
# Name: count, dtype: int64

# %%
l['Weight'].value_counts()
# Out:
# Weight
# 2.2kg      121
# 2.1kg       58
# 2.4kg       44
# 2.3kg       41
# 2.5kg       38
#           ...
# 3.52kg       1
# 2.21kg       1
# 2.191kg      1
# 2.34kg       1
# 4.0kg        1
# Name: count, Length: 179, dtype: int64

# %%
l['Weight'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Weight'>

# %%
l['Price'].value_counts()
# Out:
# Price
# 58554.7200     14
# 79866.7200     14
# 95850.7200     14
# 26586.7200     11
# 63882.7200     11
#                ..
# 26581.3920      1
# 130001.6016     1
# 18381.0672      1
# 20986.9920      1
# 41025.6000      1
# Name: count, Length: 791, dtype: int64

# %%
l['Price'].value_counts().sort_values(ascending=False)
# Out:
# Price
# 79866.7200    14
# 95850.7200    14
# 58554.7200    14
# 69210.7200    11
# 47898.7200    11
#               ..
# 17262.7200     1
# 57116.1600     1
# 9270.7200      1
# 67772.1600     1
# 78647.1408     1
# Name: count, Length: 791, dtype: int64

# %%
l['Price'].value_counts().head(15).plot(kind="barh")
# Out:
# <Axes: ylabel='Price'>

# %%
l.groupby("Company")['Price'].value_counts().sort_values(ascending=False).head(30)
# Out:
# Company  Price
# Lenovo   79866.7200    8
#          47898.7200    6
#          29250.7200    6
#          53226.7200    5
# HP       37242.7200    5
# Lenovo   26586.7200    5
# Dell     58554.7200    5
# Lenovo   50562.7200    4
# Asus     19660.3200    4
#          95850.7200    4
# Dell     24455.5200    4
#          47898.7200    4
# MSI      63882.7200    3
# Lenovo   69210.7200    3
# HP       61218.7200    3
# Acer     18594.7200    3
# HP       40705.9200    3
# Asus     58554.7200    3
# Dell     55890.7200    3
#          47365.9200    3
#          52161.1200    3
#          53226.7200    3
#          43636.3200    3
# Acer     15397.9200    3
# Dell     34578.7200    3
#          20193.1200    3
#          42943.1472    3
# Lenovo   87912.0000    3
#          63882.7200    3
#          58554.7200    3
# Name: count, dtype: int64
