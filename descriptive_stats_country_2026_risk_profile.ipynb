# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
risk=pd.read_csv("/content/country_2026_risk_profile.csv")
risk
# Out:
#         country      continent              region  income_group  records  \
# 0      Portugal         Europe     Southern Europe          High       98
# 1         China           Asia           East Asia  Upper-middle      107
# 2        Kuwait           Asia         Middle East          High       97
# 3         Spain         Europe     Southern Europe          High       98
# 4    Costa Rica  North America       Latin America  Upper-middle       98
# ..          ...            ...                 ...           ...      ...
# 93  Afghanistan           Asia          South Asia           Low      110
# 94     DR Congo         Africa  Sub-Saharan Africa           Low       92
# 95      Nigeria         Africa  Sub-Saharan Africa  Lower-middle      108
# 96      Tunisia         Africa        North Africa  Lower-middle      101
# 97  Philippines           Asia      Southeast Asia  Lower-middle       98
#
#     avg_screen_time  avg_social_media_hours  avg_sleep_hours  \
# ...

# %%
risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       98 non-null     object
#  1   continent                     98 non-null     object
#  2   region                        98 non-null     object
#  3   income_group                  98 non-null     object
#  4   records                       98 non-null     int64
#  5   avg_screen_time               98 non-null     float64
#  6   avg_social_media_hours        98 non-null     float64
#  7   avg_sleep_hours               98 non-null     float64
#  8   avg_addiction_score           98 non-null     float64
#  9   avg_mental_health_risk        98 non-null     float64
#  10  avg_physical_health_risk      98 non-null     float64
#  11  avg_academic_risk             98 non-null     float64
# ...

# %%
risk.describe()
# Out:
#           records  avg_screen_time  avg_social_media_hours  avg_sleep_hours  \
# count   98.000000        98.000000               98.000000        98.000000
# mean   102.765306         4.658805                2.488561         7.670822
# std     10.644975         0.245343                0.136907         0.097760
# min     80.000000         4.060700                2.150900         7.453600
# 25%     95.250000         4.483600                2.391925         7.606000
# 50%    101.000000         4.655800                2.490300         7.664750
# 75%    109.750000         4.831125                2.583200         7.738925
# max    138.000000         5.209600                2.786900         7.900200
#
#        avg_addiction_score  avg_mental_health_risk  avg_physical_health_risk  \
# count            98.000000               98.000000                 98.000000
# mean             48.851246               38.190432                 27.276541
# ...

# %%
risk.columns
# Out:
# Index(['country', 'continent', 'region', 'income_group', 'records',
#        'avg_screen_time', 'avg_social_media_hours', 'avg_sleep_hours',
#        'avg_addiction_score', 'avg_mental_health_risk',
#        'avg_physical_health_risk', 'avg_academic_risk',
#        'avg_digital_wellbeing', 'cyberbullying_rate', 'problematic_use_rate',
#        'high_mental_health_risk_rate', 'global_risk_rank'],
#       dtype='object')

# %%
risk.isna().sum()
# Out:
# country                         0
# continent                       0
# region                          0
# income_group                    0
# records                         0
# avg_screen_time                 0
# avg_social_media_hours          0
# avg_sleep_hours                 0
# avg_addiction_score             0
# avg_mental_health_risk          0
# avg_physical_health_risk        0
# avg_academic_risk               0
# avg_digital_wellbeing           0
# cyberbullying_rate              0
# problematic_use_rate            0
# high_mental_health_risk_rate    0
# global_risk_rank                0
# dtype: int64

# %%
risk.isna().value_counts()
# Out:
# country  continent  region  income_group  records  avg_screen_time  avg_social_media_hours  avg_sleep_hours  avg_addiction_score  avg_mental_health_risk  avg_physical_health_risk  avg_academic_risk  avg_digital_wellbeing  cyberbullying_rate  problematic_use_rate  high_mental_health_risk_rate  global_risk_rank
# False    False      False   False         False    False            False                   False            False                False                   False                     False              False                  False               False                 False                         False               98
# Name: count, dtype: int64

# %%
#measures of central tendency
#MODE

risk["country"].mode()
# Out:
# 0     Afghanistan
# 1         Algeria
# 2          Angola
# 3       Argentina
# 4       Australia
#          ...
# 93     Uzbekistan
# 94        Vietnam
# 95          Yemen
# 96         Zambia
# 97       Zimbabwe
# Name: country, Length: 98, dtype: object

# %%
risk["continent"].mode()
# Out:
# 0    Asia
# Name: continent, dtype: object

# %%
risk["region"].mode()
# Out:
# 0    Sub-Saharan Africa
# Name: region, dtype: object

# %%
risk["income_group"].mode()
# Out:
# 0    High
# Name: income_group, dtype: object

# %%
#MEAN
print("records")
mean_value = risk['records'].mean()
print("Mean value :", mean_value)

median_value = risk['records'].median()
print("Median value :", median_value)
# Out:
# reords
# Mean value : 102.76530612244898
# Median value : 101.0

# %%
print("cyberbullying_rate")
mean_value = risk['cyberbullying_rate'].mean()
print("Mean value :", mean_value)

median_value = risk['cyberbullying_rate'].median()
print("Median value :", median_value)
# Out:
# cyberbullying_rate
# Mean value : 0.15155714285714283
# Median value : 0.15565

# %%
print("problematic_use_rate")
mean_value = risk['problematic_use_rate'].mean()
print("Mean value :", mean_value)

median_value = risk['problematic_use_rate'].median()
print("Median value :", median_value)
# Out:
# problematic_use_rate
# Mean value : 0.036487755102040824
# Median value : 0.03505

# %%
print("high_mental_health_risk_rate")
mean_value = risk['high_mental_health_risk_rate'].mean()
print("Mean value :", mean_value)

median_value = risk['high_mental_health_risk_rate'].median()
print("Median value :", median_value)
# Out:
# high_mental_health_risk_rate
# Mean value : 0.0
# Median value : 0.0

# %%
print("global_risk_rank")
mean_value = risk['global_risk_rank'].mean()
print("Mean value :", mean_value)

median_value = risk['global_risk_rank'].median()
print("Median value :", median_value)
# Out:
# global_risk_rank
# Mean value : 49.5
# Median value : 49.5

# %%
#measures of dispersion
print("avg_social_media_hours")
standard=risk['avg_social_media_hours'].std()
print("standard deviation:",standard)
variance=risk['avg_social_media_hours'].var()
print("variance:",variance)
# Out:
# avg_social_media_hours
# standard deviation: 0.13690689788007382
# variance: 0.01874349868714496

# %%
print("avg_addiction_score")
standard=risk['avg_addiction_score'].std()
print("standard deviation:",standard)
variance=risk['avg_addiction_score'].var()
print("variance:",variance)
# Out:
# avg_addiction_score
# standard deviation: 1.553441048235817
# variance: 2.4131790903439936

# %%
print("avg_mental_health_risk")
standard=risk['avg_mental_health_risk'].std()
print("standard deviation:",standard)
variance=risk['avg_mental_health_risk'].var()
print("variance:",variance)
# Out:
# avg_mental_health_risk
# standard deviation: 0.9071596628695041
# variance: 0.8229386539375124

# %%
print("avg_physical_health_risk")
standard=risk['avg_physical_health_risk'].std()
print("standard deviation:",standard)
variance=risk['avg_physical_health_risk'].var()
print("variance:",variance)
# Out:
# avg_physical_health_risk
# standard deviation: 1.906039542640883
# variance: 3.632986738110666

# %%
print("avg_academic_risk")
standard=risk['avg_academic_risk'].std()
print("standard deviation:",standard)
variance=risk['avg_academic_risk'].var()
print("variance:",variance)
# Out:
# avg_academic_risk
# standard deviation: 0.6800541280761426
# variance: 0.46247361711340257

# %%
#measures of frequency

plt.hist(risk["avg_screen_time"],color='red',edgecolor='black')
plt.show()

# %%
sns.histplot(risk["avg_screen_time"],kde=True)
plt.show()

# %%
print("kurtosis of (avg_screen_time)")
risk["avg_screen_time"].head(15).kurtosis()
# Out:
# kurtosis of (avg_screen_time)
# np.float64(0.07919604352003162)

# %%
print("skewness of (avg_screen_time)")
risk["avg_screen_time"].head(15).skew()
# Out:
# skewness of (avg_screen_time)
# np.float64(0.38664798387767557)

# %%
sns.histplot(risk["avg_academic_risk"],kde=True,bins=5)
plt.show()

# %%
print("kurtosis of (avg_academic_risk)")
risk["avg_academic_risk"].head(15).kurtosis()
# Out:
# kurtosis of (avg_academic_risk)
# np.float64(-0.6499797768345572)

# %%
print("skewness of (avg_academic_risk)")
risk["avg_academic_risk"].head(15).skew()
# Out:
# skewness of (avg_academic_risk)
# np.float64(-0.19654118120845074)

# %%
sns.boxplot(risk['global_risk_rank'])
plt.show()

# %%
print("kurtosis of (global_risk_rank)")
risk["global_risk_rank"].head(15).kurtosis()
# Out:
# kurtosis of (global_risk_rank)
# np.float64(-1.1999999999999997)

# %%
print("skewness of (global_risk_rank)")
risk["global_risk_rank"].head(15).skew()
# Out:
# skewness of (global_risk_rank)
# np.float64(0.0)

# %%
sns.barplot(x='avg_social_media_hours',y='avg_physical_health_risk',data=risk)
plt.show()

# %%
sns.scatterplot(x='avg_social_media_hours',y='avg_physical_health_risk',data=risk)
plt.show()

# %%
sns.boxenplot(x='avg_sleep_hours',data=risk)
# Out:
# <Axes: xlabel='avg_sleep_hours'>

# %%
sns.lineplot(x='avg_sleep_hours',y='avg_mental_health_risk',data=risk)
# Out:
# <Axes: xlabel='avg_sleep_hours', ylabel='avg_mental_health_risk'>

# %%
print("kurtosis of (avg_sleep_hours)")
risk["avg_sleep_hours"].head(15).kurtosis()
# Out:
# kurtosis of (avg_sleep_hours)
# np.float64(0.27209453772265313)

# %%
print("skewness of (avg_sleep_hours)")
risk["avg_sleep_hours"].head(15).skew()
# Out:
# skewness of (avg_sleep_hours)
# np.float64(0.2743379937264178)
