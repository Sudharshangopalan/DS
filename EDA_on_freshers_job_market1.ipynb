# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot

# %%
f=pd.read_csv("/content/fresher_hiring_india_dataset.csv")
f
# Out:
#       candidate_id       full_name  gender  age  graduation_year  \
# 0                1  Deepika Shukla  Female   23             2021
# 1                2    Piyush Reddy    Male   25             2022
# 2                3    Itisha Arora  Female   21             2024
# 3                4     Darshan Dey    Male   22             2022
# 4                5      Uma Grewal  Female   25             2020
# ...            ...             ...     ...  ...              ...
# 4995          4996    Bhumi Shukla  Female   20             2021
# 4996          4997    Hemant Rajan    Male   24             2023
# 4997          4998     Ojaswi More  Female   21             2020
# 4998          4999    Ojaswi Kumar  Female   23             2021
# 4999          5000   Shivam Sharma    Male   25             2020
#
#                            college     degree                  branch  cgpa  \
# 0                         BITS Goa       B.E.              Electrical  5.89
# ...

# %%
f.shape
# Out:
# (5000, 30)

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   candidate_id            5000 non-null   int64
#  1   full_name               5000 non-null   object
#  2   gender                  5000 non-null   object
#  3   age                     5000 non-null   int64
#  4   graduation_year         5000 non-null   int64
#  5   college                 5000 non-null   object
#  6   degree                  5000 non-null   object
#  7   branch                  5000 non-null   object
#  8   cgpa                    5000 non-null   float64
#  9   backlogs                5000 non-null   int64
#  10  gap_year                5000 non-null   object
#  11  prior_internship        5000 non-null   object
#  12  projects_count          5000 non-null   int64
#  13  certifications_count    5000 non-null   int64
# ...

# %%
f.columns
# Out:
# Index(['candidate_id', 'full_name', 'gender', 'age', 'graduation_year',
#        'college', 'degree', 'branch', 'cgpa', 'backlogs', 'gap_year',
#        'prior_internship', 'projects_count', 'certifications_count',
#        'top_skills', 'platform', 'company_applied', 'sector', 'job_role',
#        'work_type', 'job_location', 'application_date', 'hiring_stage',
#        'interview_rounds', 'response_time_days', 'offered_salary_inr',
#        'linkedin_connections', 'profile_completion_pct', 'linkedin_premium',
#        'referral_applied'],
#       dtype='object')

# %%
f.isnull().sum()
# Out:
# candidate_id                 0
# full_name                    0
# gender                       0
# age                          0
# graduation_year              0
# college                      0
# degree                       0
# branch                       0
# cgpa                         0
# backlogs                     0
# gap_year                     0
# prior_internship             0
# projects_count               0
# certifications_count         0
# top_skills                   0
# platform                     0
# company_applied              0
# sector                       0
# job_role                     0
# work_type                    0
# job_location                 0
# application_date             0
# hiring_stage                 0
# interview_rounds          3182
# response_time_days           0
# offered_salary_inr        4378
# linkedin_connections         0
# profile_completion_pct       0
# linkedin_premium          3901
# referral_applied             0
# ...

# %%
f.describe()
# Out:
#        candidate_id          age  graduation_year         cgpa     backlogs  \
# count   5000.000000  5000.000000      5000.000000  5000.000000  5000.000000
# mean    2500.500000    23.501800      2022.491000     7.742102     1.500200
# std     1443.520003     2.293262         1.705785     1.304093     1.119397
# min        1.000000    20.000000      2020.000000     5.500000     0.000000
# 25%     1250.750000    21.000000      2021.000000     6.620000     0.000000
# 50%     2500.500000    24.000000      2022.000000     7.730000     1.000000
# 75%     3750.250000    26.000000      2024.000000     8.890000     3.000000
# max     5000.000000    27.000000      2025.000000    10.000000     3.000000
#
#        projects_count  certifications_count  interview_rounds  \
# count     5000.000000            5000.00000       1818.000000
# mean         2.998000               2.49780          3.036304
# std          1.999699               1.70299          1.412189
# ...

# %%
f['full_name'].value_counts().head(10)
# Out:
# full_name
# Onkar Lal             5
# Indira Sandhu         5
# Harish Sodhi          4
# Ojaswi Joshi          4
# Yash Menon            4
# Mayank Murthy         4
# Divya Kapoor          3
# Raghav Subramaniam    3
# Yogesh Oberoi         3
# Raghav Das            3
# Name: count, dtype: int64

# %%
f["gender"].value_counts()
# Out:
# gender
# Male                 2682
# Female               2175
# Prefer not to say     143
# Name: count, dtype: int64

# %%
f.groupby("full_name")["gender"].value_counts()
# Out:
# full_name           gender
# Aarav Ahuja         Male      1
# Aarav Anand         Male      1
# Aarav Arora         Male      1
# Aarav Bajaj         Male      1
# Aarav Balakrishnan  Male      1
#                              ..
# Zara Singh          Female    1
# Zara Soni           Female    1
# Zara Subramaniam    Female    1
# Zara Swamy          Female    1
# Zara Verma          Female    1
# Name: count, Length: 4353, dtype: int64

# %%
f["gender"].value_counts().plot(kind="bar")
#sns.barplot(x='gender',y='age',data=f)
# Out:
# <Axes: xlabel='gender'>

# %%
f["graduation_year"].value_counts()
# Out:
# graduation_year
# 2022    854
# 2020    841
# 2024    830
# 2023    828
# 2025    824
# 2021    823
# Name: count, dtype: int64

# %%
f["graduation_year"].value_counts().plot(kind="pie",autopct='%1.2f%%',startangle=90)
# Out:
# <Axes: ylabel='count'>

# %%
f.groupby("gender")["graduation_year"].value_counts()
# Out:
# gender             graduation_year
# Female             2025               383
#                    2023               377
#                    2024               361
#                    2022               360
#                    2020               356
#                    2021               338
# Male               2022               464
#                    2020               463
#                    2021               456
#                    2024               450
#                    2023               432
#                    2025               417
# Prefer not to say  2022                30
#                    2021                29
#                    2025                24
#                    2020                22
#                    2023                19
#                    2024                19
# Name: count, dtype: int64

# %%
sns.boxplot(x='gender',y='graduation_year',data=f)
# Out:
# <Axes: xlabel='gender', ylabel='graduation_year'>

# %%
f.groupby('gender')['age'].value_counts().sort_values()
# Out:
# gender             age
# Prefer not to say  25      13
#                    24      14
#                    27      15
#                    20      17
#                    23      17
#                    21      20
#                    22      20
#                    26      27
# Female             25     234
#                    20     262
#                    23     266
#                    26     266
#                    27     276
#                    21     282
#                    22     286
#                    24     303
# Male               22     324
#                    25     327
#                    26     327
#                    23     327
#                    20     329
#                    21     344
#                    24     350
#                    27     354
# Name: count, dtype: int64

# %%
f.groupby('gender')['age'].value_counts().sort_values().plot(kind="box")
# Out:
# <Axes: >

# %%
f["college"].value_counts()
# Out:
# college
# IIM Bangalore                      112
# Pune University                    107
# XLRI Jamshedpur                    106
# IIM Ahmedabad                      102
# Delhi University                   101
# BITS Pilani                        100
# Bangalore University               100
# IIT Delhi                          100
# IIT Kanpur                          98
# NSUT Delhi                          98
# NIT Calicut                         98
# JNTUH Hyderabad                     96
# Anna University Chennai             95
# Kalinga University                  95
# NIT Warangal                        95
# Lovely Professional University      95
# BITS Hyderabad                      94
# SVNIT Surat                         94
# Symbiosis Pune                      93
# BITS Goa                            93
# HBTU Kanpur                         93
# NIT Surathkal                       92
# Osmania University Hyderabad        91
# Jadavpur University Kolkata         91
# ...

# %%
f["college"].value_counts().head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='college'>

# %%
f["college"].value_counts().tail(15).plot(kind='bar')
# Out:
# <Axes: xlabel='college'>

# %%
f.groupby("gender")["college"].value_counts().head(20)
# Out:
# gender  college
# Female  IIM Bangalore                      60
#         Lovely Professional University     50
#         IIT Delhi                          47
#         Nirma University Ahmedabad         47
#         Pune University                    47
#         XLRI Jamshedpur                    47
#         IIM Ahmedabad                      46
#         NIT Calicut                        46
#         Manipal Institute of Technology    45
#         Amity University Noida             44
#         BITS Hyderabad                     43
#         SP Jain Mumbai                     43
#         SRM University Chennai             43
#         BITS Pilani                        42
#         HBTU Kanpur                        42
#         JNTUH Hyderabad                    42
#         IIT Hyderabad                      41
#         DTU Delhi                          40
#         Delhi University                   40
#         IIM Calcutta                       40
# ...

# %%
f.groupby("college")["degree"].value_counts().sort_values()
# Out:
# college                      degree
# PES University Bangalore     M.Tech        2
# Pune University              B.E.          2
# IIT Roorkee                  MBA           2
# Jadavpur University Kolkata  BCA           2
# HBTU Kanpur                  B.Tech        2
#                                           ..
# Bangalore University         B.Com        16
# IIT Madras                   B.Tech       17
# Pune University              BBA          18
# IIM Bangalore                BCA          18
# VIT Vellore                  B.Sc (CS)    19
# Name: count, Length: 560, dtype: int64

# %%
f["degree"].value_counts()
# Out:
# degree
# B.E.         555
# BBA          536
# B.Tech       523
# BCA          515
# B.Com        509
# B.Sc (CS)    493
# M.Tech       487
# MCA          481
# MBA          463
# B.Sc (IT)    438
# Name: count, dtype: int64

# %%
sns.histplot(f["degree"],bins=10,kde=True)
# Out:
# <Axes: xlabel='degree', ylabel='Count'>

# %%
f["branch"].value_counts()
# Out:
# branch
# Computer Applications          996
# Computer Science               787
# Information Technology         509
# Finance                        401
# Marketing                      214
# HR                             210
# Commerce                       166
# Accounting                     147
# Data Science                   145
# Business Administration        127
# Electronics                    117
# Civil                          112
# Mechanical                     110
# Electrical                     109
# AI/ML                           99
# Software Engineering            96
# VLSI                            95
# Operations                      86
# Business Analytics              81
# Strategy                        76
# Chemical Engineering            71
# Electronics & Communication     63
# Mechanical Engineering          63
# Electrical Engineering          60
# Civil Engineering               60
# Name: count, dtype: int64

# %%
f.groupby("degree")['branch'].value_counts()
# Out:
# degree     branch
# B.Com      Finance                        196
#            Commerce                       166
#            Accounting                     147
# B.E.       Electronics                    117
#            Civil                          112
#            Mechanical                     110
#            Electrical                     109
#            Computer Science               107
# B.Sc (CS)  Computer Science               493
# B.Sc (IT)  Information Technology         438
# B.Tech     Computer Science                72
#            Chemical Engineering            71
#            Information Technology          71
#            Data Science                    63
#            Electronics & Communication     63
#            Mechanical Engineering          63
#            Civil Engineering               60
#            Electrical Engineering          60
# BBA        HR                             148
#            Finance                        138
# ...

# %%
sns.scatterplot(x='degree',y='branch',data=f)
# Out:
# <Axes: xlabel='degree', ylabel='branch'>

# %%
f["cgpa"].value_counts()
# Out:
# cgpa
# 6.61    21
# 9.65    21
# 7.21    20
# 6.10    20
# 7.41    19
#         ..
# 7.96     4
# 6.09     4
# 7.61     4
# 8.45     3
# 7.57     3
# Name: count, Length: 451, dtype: int64

# %%
f.groupby("gender")["cgpa"].value_counts().head(20)
# Out:
# gender  cgpa
# Female  7.66    12
#         8.97    12
#         9.46    12
#         6.65    11
#         5.71    10
#         7.19    10
#         7.41    10
#         8.59    10
#         9.39    10
#         9.40    10
#         5.92     9
#         6.05     9
#         6.94     9
#         7.65     9
#         8.09     9
#         8.38     9
#         8.68     9
#         8.95     9
#         9.00     9
#         9.42     9
# Name: count, dtype: int64

# %%
sns.boxplot(x='gender',y='cgpa',data=f)
# Out:
# <Axes: xlabel='gender', ylabel='cgpa'>

# %%
f.groupby("branch")["cgpa"].value_counts().head(20)
# Out:
# branch  cgpa
# AI/ML   5.55    2
#         5.68    2
#         6.20    2
#         6.64    2
#         6.86    2
#         7.92    2
#         8.23    2
#         8.73    2
#         9.13    2
#         9.36    2
#         9.80    2
#         5.50    1
#         5.61    1
#         5.70    1
#         5.75    1
#         5.79    1
#         5.80    1
#         5.82    1
#         5.87    1
#         5.90    1
# Name: count, dtype: int64

# %%
f["backlogs"].value_counts()
# Out:
# backlogs
# 3    1255
# 0    1252
# 1    1250
# 2    1243
# Name: count, dtype: int64

# %%
f["backlogs"].value_counts().plot(kind='pie',autopct='%1.2f%%')
plot.title("Backlogs")
# Out:
# Text(0.5, 1.0, 'Backlogs')

# %%
f["gap_year"].value_counts()
# Out:
# gap_year
# No     4416
# Yes     584
# Name: count, dtype: int64

# %%
f["prior_internship"].value_counts()
# Out:
# prior_internship
# No     2770
# Yes    2230
# Name: count, dtype: int64

# %%
f["projects_count"].value_counts()
# Out:
# projects_count
# 1    734
# 5    734
# 4    715
# 0    709
# 2    704
# 6    702
# 3    702
# Name: count, dtype: int64

# %%
f.groupby("branch")["projects_count"].value_counts()
# Out:
# branch  projects_count
# AI/ML   1                 21
#         3                 18
#         4                 17
#         6                 16
#         0                 11
#                           ..
# VLSI    1                 14
#         5                 14
#         6                 14
#         4                 13
#         2                  9
# Name: count, Length: 175, dtype: int64

# %%
f["top_skills"].value_counts()
# Out:
# top_skills
# Scala | Ruby on Rails                                                 5
# JavaScript | Networking                                               5
# Swift | Kotlin                                                        4
# Teamwork | GraphQL                                                    4
# Communication | Django                                                4
#                                                                      ..
# Selenium | Networking | TypeScript | Cybersecurity | Data Analysis    1
# TensorFlow | PHP | Figma | Spark                                      1
# TypeScript | Scala | Docker | Leadership                              1
# React | TensorFlow | Power BI | Ruby on Rails | Excel                 1
# JavaScript | GraphQL                                                  1
# Name: count, Length: 4697, dtype: int64

# %%
f["platform"].value_counts()
# Out:
# platform
# LinkedIn            1099
# Naukri               959
# Indeed               472
# Internshala          395
# Campus Placement     334
# Unstop               307
# Referral             253
# Cutshort             253
# AngelList            203
# HackerEarth          183
# Glassdoor            102
# Monster               99
# Foundit               55
# Apna                  55
# IIMJobs               53
# Shine                 51
# Hirist                39
# Freshersworld         32
# WorkIndia             31
# TimesJobs             25
# Name: count, dtype: int64

# %%
f["platform"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='platform'>

# %%
f.groupby("top_skills")["platform"].value_counts().sort_values(ascending=False)
# Out:
# top_skills                                                 platform
# Hive | Linux                                               Naukri              4
# React | REST APIs                                          Campus Placement    3
# Data Analysis | Node.js                                    LinkedIn            2
# Tableau | SQL                                              Naukri              2
# Python | TensorFlow                                        LinkedIn            2
#                                                                               ..
# Hadoop | Problem Solving | Excel | Deep Learning | Python  LinkedIn            1
# Hadoop | Problem Solving | Docker                          Indeed              1
# Hadoop | Power BI | TypeScript | Teamwork | Cybersecurity  HackerEarth         1
# Hadoop | Power BI | Excel                                  Shine               1
# Hadoop | REST APIs | Teamwork                              LinkedIn            1
# ...

# %%
f.groupby("gender")["platform"].value_counts()
# Out:
# gender             platform
# Female             LinkedIn            491
#                    Naukri              426
#                    Indeed              190
#                    Internshala         170
#                    Campus Placement    147
#                    Unstop              127
#                    Referral            117
#                    Cutshort            111
#                    HackerEarth          78
#                    AngelList            76
#                    Glassdoor            45
#                    Monster              43
#                    Shine                26
#                    Apna                 25
#                    Foundit              24
#                    IIMJobs              22
#                    Hirist               18
#                    WorkIndia            17
#                    Freshersworld        15
#                    TimesJobs             7
# Male               LinkedIn            582
# ...

# %%
sns.boxplot(x='gender',y='platform',data=f)
# Out:
# <Axes: xlabel='gender', ylabel='platform'>

# %%
f["company_applied"].value_counts()
# Out:
# company_applied
# Amazon India         91
# Axis Bank            90
# Ola                  86
# Fractal Analytics    85
# Barclays India       85
#                      ..
# Zomato               62
# Wipro                62
# Deloitte             60
# Bajaj Finserv        60
# BigBasket            56
# Name: count, Length: 68, dtype: int64

# %%
f["company_applied"].value_counts().head(15).plot(kind='barh')
# Out:
# <Axes: ylabel='company_applied'>

# %%
f.groupby("platform")["company_applied"].value_counts()
# Out:
# platform   company_applied
# AngelList  Capgemini                  8
#            Coforge                    8
#            Upstox                     7
#            BYJU's                     6
#            BigBasket                  6
#                                      ..
# WorkIndia  TCS                        1
#            Texas Instruments India    1
#            Tiger Analytics            1
#            Uber India                 1
#            Zerodha                    1
# Name: count, Length: 1030, dtype: int64

# %%
f["sector"].value_counts()
# Out:
# sector
# E-commerce               384
# Banking & Finance        368
# AgriTech                 366
# Telecom                  364
# Media & Entertainment    361
# FinTech                  358
# EdTech                   357
# Retail                   357
# Consulting               357
# HealthTech               355
# Automotive               351
# Manufacturing            350
# Logistics                343
# IT/Software              329
# Name: count, dtype: int64

# %%
f["sector"].value_counts().plot(kind='pie',autopct='%2.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
f.groupby("age")["sector"].value_counts().sort_index(ascending=False)
# Out:
# age  sector
# 27   Telecom                  44
#      Retail                   47
#      Media & Entertainment    59
#      Manufacturing            41
#      Logistics                35
#                               ..
# 20   E-commerce               46
#      Consulting               43
#      Banking & Finance        53
#      Automotive               44
#      AgriTech                 41
# Name: count, Length: 112, dtype: int64

# %%
sns.barplot(x='age',y='sector',data=f)
# Out:
# <Axes: xlabel='age', ylabel='sector'>

# %%
f["job_role"].value_counts()
# Out:
# job_role
# Embedded Engineer              188
# Business Analyst               187
# UX Designer                    181
# Software Engineer              181
# Recruiter                      181
# Systems Engineer               180
# Full Stack Developer           180
# Product Manager                179
# QA Engineer                    178
# Digital Marketing Executive    174
# Data Scientist                 173
# Operations Analyst             173
# Content Writer                 168
# SEO Analyst                    167
# Finance Analyst                167
# Database Administrator         165
# Cloud Engineer                 164
# Backend Developer              163
# DevOps Engineer                163
# Technical Support Engineer     163
# ML Engineer                    158
# Android Developer              158
# Network Engineer               155
# Data Analyst                   154
# Cybersecurity Analyst          153
# Sales Executive                153
# ...

# %%
f["work_type"].value_counts()
# Out:
# work_type
# Full-time     2740
# Internship    1407
# Contract       515
# Part-time      338
# Name: count, dtype: int64

# %%
f["work_type"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='work_type'>

# %%
f.groupby("work_type")["job_role"].value_counts().head(25)
# Out:
# work_type  job_role
# Contract   Business Analyst               24
#            Embedded Engineer              24
#            Systems Engineer               23
#            ML Engineer                    22
#            Product Manager                22
#            Software Engineer              22
#            SEO Analyst                    21
#            Cloud Engineer                 20
#            Finance Analyst                19
#            UX Designer                    19
#            iOS Developer                  19
#            Android Developer              18
#            Digital Marketing Executive    18
#            Operations Analyst             18
#            Technical Support Engineer     18
#            Database Administrator         17
#            QA Engineer                    17
#            Cybersecurity Analyst          16
#            Network Engineer               16
#            Recruiter                      16
# ...

# %%
sns.barplot(x='work_type',y='job_role',data=f)
# Out:
# <Axes: xlabel='work_type', ylabel='job_role'>

# %%
f["hiring_stage"].value_counts()
# Out:
# hiring_stage
# Applied                1434
# Shortlisted             872
# Online Assessment       717
# Offer                   622
# Technical Interview     493
# Rejected                374
# HR Interview            329
# Withdrawn               159
# Name: count, dtype: int64

# %%
f["hiring_stage"].value_counts().plot(kind='pie',autopct='%2.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
f.groupby("gender")["hiring_stage"].value_counts()
# Out:
# gender             hiring_stage
# Female             Applied                623
#                    Shortlisted            399
#                    Online Assessment      322
#                    Offer                  253
#                    Technical Interview    193
#                    Rejected               172
#                    HR Interview           148
#                    Withdrawn               65
# Male               Applied                774
#                    Shortlisted            454
#                    Online Assessment      372
#                    Offer                  343
#                    Technical Interview    284
#                    Rejected               191
#                    HR Interview           173
#                    Withdrawn               91
# Prefer not to say  Applied                 37
#                    Offer                   26
#                    Online Assessment       23
#                    Shortlisted             19
# ...

# %%
f["interview_rounds"].value_counts()
# Out:
# interview_rounds
# 4.0    378
# 3.0    376
# 5.0    370
# 1.0    358
# 2.0    336
# Name: count, dtype: int64

# %%
f.groupby("age")["interview_rounds"].value_counts()
# Out:
# age  interview_rounds
# 20   4.0                 52
#      3.0                 45
#      1.0                 44
#      2.0                 38
#      5.0                 34
# 21   3.0                 54
#      5.0                 47
#      1.0                 41
#      2.0                 39
#      4.0                 34
# 22   3.0                 63
#      5.0                 53
#      4.0                 51
#      2.0                 49
#      1.0                 45
# 23   2.0                 53
#      1.0                 52
#      3.0                 49
#      4.0                 39
#      5.0                 36
# 24   4.0                 61
#      5.0                 51
#      1.0                 45
#      2.0                 45
#      3.0                 43
# 25   5.0                 53
#      1.0                 51
#      3.0                 38
#      4.0                 34
#      2.0                 33
# 26   4.0                 51
#      3.0                 44
# ...

# %%
sns.boxplot(x='age',y='interview_rounds',data=f)
# Out:
# <Axes: xlabel='age', ylabel='interview_rounds'>

# %%
f["response_time_days"].value_counts()
# Out:
# response_time_days
# 41    137
# 24    134
# 6     130
# 29    126
# 39    125
# 12    124
# 7     124
# 10    123
# 37    123
# 9     122
# 38    122
# 8     121
# 32    120
# 14    120
# 27    119
# 40    116
# 42    115
# 22    114
# 45    113
# 34    113
# 35    112
# 4     112
# 26    112
# 21    112
# 30    108
# 19    108
# 18    108
# 17    108
# 3     107
# 36    106
# 1     106
# 33    104
# 44    103
# 43    103
# 16    103
# 25     99
# 23     99
# 11     99
# 31     98
# 20     98
# 5      98
# 15     94
# 28     93
# 13     85
# 2      84
# Name: count, dtype: int64

# %%
f["offered_salary_inr"].value_counts()
# Out:
# offered_salary_inr
# 387946.0     1
# 34090.0      1
# 720172.0     1
# 873948.0     1
# 711694.0     1
#             ..
# 1564763.0    1
# 259363.0     1
# 852819.0     1
# 18415.0      1
# 452897.0     1
# Name: count, Length: 622, dtype: int64

# %%
f["linkedin_connections"].value_counts()
# Out:
# linkedin_connections
# 997     8
# 443     7
# 1030    7
# 1488    7
# 2196    7
#        ..
# 286     1
# 2416    1
# 1914    1
# 2130    1
# 540     1
# Name: count, Length: 2418, dtype: int64

# %%
f.groupby("gender")["linkedin_connections"].value_counts()
# Out:
# gender             linkedin_connections
# Female             1488                    6
#                    443                     5
#                    624                     5
#                    632                     5
#                    1030                    5
#                                           ..
# Prefer not to say  2957                    1
#                    2963                    1
#                    2966                    1
#                    2969                    1
#                    2981                    1
# Name: count, Length: 3450, dtype: int64

# %%
f["referral_applied"].value_counts()
# Out:
# referral_applied
# No     4201
# Yes     799
# Name: count, dtype: int64

# %%
f["referral_applied"].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
t = (f['referral_applied'] == 'yes').value_counts()
print(t)
# Out:
# referral_applied
# False    5000
# Name: count, dtype: int64

# %%
f.groupby("age")["referral_applied"].value_counts()
# Out:
# age  referral_applied
# 20   No                  497
#      Yes                 111
# 21   No                  534
#      Yes                 112
# 22   No                  540
#      Yes                  90
# 23   No                  518
#      Yes                  92
# 24   No                  575
#      Yes                  92
# 25   No                  479
#      Yes                  95
# 26   No                  510
#      Yes                 110
# 27   No                  548
#      Yes                  97
# Name: count, dtype: int64

# %%
sns.boxplot(x='age',y='referral_applied',data=f)
# Out:
# <Axes: xlabel='age', ylabel='referral_applied'>

# %%
f["application_date"].value_counts()
# Out:
# application_date
# 2021-11-21    10
# 2021-02-18    10
# 2022-02-06    10
# 2023-12-31    10
# 2023-02-17    10
#               ..
# 2021-03-31     1
# 2023-05-11     1
# 2024-02-21     1
# 2024-03-21     1
# 2023-02-10     1
# Name: count, Length: 1409, dtype: int64

# %%
f.groupby('top_skills')["platform"].value_counts().sort_values(ascending=False)
# Out:
# top_skills                                                 platform
# Hive | Linux                                               Naukri              4
# React | REST APIs                                          Campus Placement    3
# Data Analysis | Node.js                                    LinkedIn            2
# Tableau | SQL                                              Naukri              2
# Python | TensorFlow                                        LinkedIn            2
#                                                                               ..
# Hadoop | Problem Solving | Excel | Deep Learning | Python  LinkedIn            1
# Hadoop | Problem Solving | Docker                          Indeed              1
# Hadoop | Power BI | TypeScript | Teamwork | Cybersecurity  HackerEarth         1
# Hadoop | Power BI | Excel                                  Shine               1
# Hadoop | REST APIs | Teamwork                              LinkedIn            1
# ...
